# %%
# !pip install PyMongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 17.1 MB/s eta 0:00:00
# ...

# %%
# !python -m pip install "pymongo[srv]"
# Out:
# ...
# WARNING: pymongo 4.8.0 does not provide the extra 'srv'
# ...

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb+srv://zj-admin:1234@train.lk4fu.mongodb.net/?retryWrites=true&w=majority&appName=Train")
mydb=myclient["friends"]

# %%
print(myclient.list_database_names())
# Out:
# ['admin', 'local']

# %%
mycol = mydb["casts"]

# %%
print(mydb.list_collection_names())
# Out:
# []

# %%
mylist =[
     { "name": "Jennifer Aniston", "role": "Rachel Green" , "gender":"Female"},
     { "name": "Courteney Cox", "role": "Monica Geller"},
     { "name": "Lisa Kudrow", "role": "Phoebe Buffay" , "nationality":"American"},
     { "name": "Matt LeBlanc"},
     { "name": "Matthew Perry", "role": "Chandler Bing" , "gender":"Male"},
     { "name": "David Schwimmer", "role": "Ross Geller" , "gender":"Male","nationality":"American" },
]
x = mycol.insert_many(mylist)

# %%
query = ({"name": {"$regex": r'^.{1,11}$'}})
result = mycol.find(query)

# Print the results
for doc in result:
    print(doc)
# Out:
# {'_id': ObjectId('66e551f8bc703d1ff8583ba4'), 'name': 'Lisa Kudrow', 'role': 'Phoebe Buffay', 'nationality': 'American'}
